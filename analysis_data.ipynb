# %% [markdown]
# # 1 Exploratory Dataset Analysis - Book Scraper

# %% [markdown]
# # 2 Import Libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 3 Information Dataset

# %% [markdown]
# <li>This data set was scrapped using python from http://books.toscrape.com/ which is a fictional book store. It contains 1000 books, with different categories, star ratings and prices. This data set can be used by anyone who wants to practice data cleaning and simple data manipulations.</li>

# %% [markdown]
# # 3.1 Content of Dataset

# %% [markdown]
# <li>title = Judul buku</li>
# <li>book_category = Kategory atau genre buku</li>
# <li>star_rating = Indeks tingkat review</li>
# <li>price = Harga buku</li>
# <li>stock = Buku tersedia atau tidak</li>
# <li>quantity = Jumlah buku</li>

# %% [markdown]
# # 4 Data Preparation

# %%
dataku = pd.read_csv("books_scraped.csv")

# %%
dataku.head()
# kalau dataku.tail() 5 data terakhir
# Out:
#                                    title       book_category  star_rating  \
# 0                   A Light in the Attic              Poetry            3
# 1                     Tipping the Velvet  Historical Fiction            1
# 2                             Soumission             Fiction            1
# 3                          Sharp Objects             Mystery            4
# 4  Sapiens: A Brief History of Humankind             History            5
#
#    price     stock  quantity
# 0  51.77  In stock        22
# 1  53.74  In stock        20
# 2  50.10  In stock        20
# 3  47.82  In stock        20
# 4  54.23  In stock        20

# %%
dataku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1000 non-null   object
#  1   book_category  1000 non-null   object
#  2   star_rating    1000 non-null   int64
#  3   price          1000 non-null   float64
#  4   stock          1000 non-null   object
#  5   quantity       1000 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %% [markdown]
# # 5 Data Cleaning

# %% [markdown]
# # 5.1 Check for Missing Value

# %%
dataku.isnull().sum()
# Out:
# title            0
# book_category    0
# star_rating      0
# price            0
# stock            0
# quantity         0
# dtype: int64

# %% [markdown]
# # 5.2 Check for Duplicate Value

# %%
dataku[dataku.duplicated()].sum()
# Out:
# title            0.0
# book_category    0.0
# star_rating      0.0
# price            0.0
# stock            0.0
# quantity         0.0
# dtype: float64

# %% [markdown]
# # 6 Data Visualization

# %% [markdown]
# # 6.1 Describe Dataset

# %%
dataku.describe()
# Out:
#        star_rating       price     quantity
# count  1000.000000  1000.00000  1000.000000
# mean      2.923000    35.07035     8.585000
# std       1.434967    14.44669     5.654622
# min       1.000000    10.00000     1.000000
# 25%       2.000000    22.10750     3.000000
# 50%       3.000000    35.98000     7.000000
# 75%       4.000000    47.45750    14.000000
# max       5.000000    59.99000    22.000000

# %% [markdown]
# # 6.2 Brachart of Rate Review

# %%
sns.countplot(x=dataku["star_rating"])
# Out:
# <AxesSubplot:xlabel='star_rating', ylabel='count'>

# %% [markdown]
# Pada gambar terlihat buku dengan rate bintang 1 yang tersedia sangat banyak dibanding dengan buku dengan rate review diatasnya

# %%
sns.displot(dataku.book_category)

# %%
sns.pairplot(dataku, hue='star_rating')

# %%
dataku['book_category'].value_counts()
# Out:
# Default               152
# Nonfiction            110
# Sequential Art         75
# Add a comment          67
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                35
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Thriller               11
# Travel                 11
# Philosophy             11
# Humor                  10
# Autobiography           9
# Art                     8
# Psychology              7
# Religion                7
# Spirituality            6
# Christian Fiction       6
# New Adult               6
# Sports and Games        5
# Biography               5
# Self Help               5
# ...

# %%
sns.countplot(x='book_category', hue='star_rating', data=dataku)
# Out:
# <AxesSubplot:xlabel='book_category', ylabel='count'>
